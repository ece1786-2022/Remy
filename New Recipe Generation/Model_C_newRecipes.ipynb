# %% [markdown]
# # Prerequisites

# %%
! pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 451 kB 19.1 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 53.2 MB/s
# ...
#      |████████████████████████████████| 182 kB 56.1 MB/s
# ...
#      |████████████████████████████████| 212 kB 72.1 MB/s
# ...
#      |████████████████████████████████| 132 kB 55.7 MB/s
# ...
#      |████████████████████████████████| 127 kB 15.7 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 32.1 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !pip install evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 72 kB 779 kB/s
# ...

# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/ece1786-project/validation
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/ece1786-project/validation

# %%
import transformers
from datasets import Dataset
from transformers import AutoTokenizer
import pandas as pd
import torch 
from transformers import AutoModelForCausalLM
from transformers import Trainer, TrainingArguments
import evaluate
import numpy as np

# %%
device = torch.device('cpu')
tokenizer = AutoTokenizer.from_pretrained("gpt2", use_fast=True)
model = AutoModelForCausalLM.from_pretrained("../gpt2_combined")
# Out:
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# #Functions

# %%
def create_propmts(name, prefix):
    return prefix + "RECIPE NAME\n" + name + " \n\n" + prefix + "RECIPE INGREDIENTS\n"

# %%
def get_recipe(name, model, prefix):
  prompts = create_propmts(name, prefix)
  encoded_prompt = tokenizer(prompts, return_tensors="pt").input_ids.to(device)
  generated_sequence = model.generate(encoded_prompt, do_sample=True, max_length=600, temperature = 0.5, return_dict_in_generate=True, output_scores=True)
  decoded_sequence = tokenizer.batch_decode(generated_sequence.sequences, skip_special_tokens=True)[0]
  return decoded_sequence

# %% [markdown]
# #Drinks

# %%
prompts = "DRINK " + "RECIPE NAME\n"
encoded_prompt = tokenizer(prompts, return_tensors="pt").input_ids.to(device)
generated_sequence = model.generate(encoded_prompt, do_sample=True, max_length=600, temperature = 0.5, return_dict_in_generate=True, output_scores=True)
decoded_sequence = tokenizer.batch_decode(generated_sequence.sequences, skip_special_tokens=True)[0]
print(decoded_sequence)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# DRINK RECIPE NAME
# CBD Moscow Mule
#
# DRINK RECIPE INGREDIENTS
# 2 ounces vodka
# 1 ounce lime juice, freshly squeezed
# 1/2 ounce CBD-ginger syrup*
# Ginger beer, to top
# Garnish: mint sprig
# Garnish: lime wheel
#
# DRINK RECIPE INSTRUCTIONS
# Add the vodka, lime juice and CBD-ginger syrup into a mule mug or highball glass filled with ice.
# Top with ginger beer and stir briefly and gently to combine.
# Garnish with a mint sprig and a lime wheel.

# %%
print(get_recipe("wave rider", model, prefix="DRINK "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# DRINK RECIPE NAME
# wave rider
#
# DRINK RECIPE INGREDIENTS
# 1 1/2 ounces El Dorado five-year-old rum
# 1/2 ounce Coco Lopez cream of coconut
# 1/2 ounce St. George pear liqueur
# 1/2 ounce cinnamon simple syrup
# 1/2 ounce coconut milk
# Garnish: nutmeg, freshly grated
#
# DRINK RECIPE INSTRUCTIONS
# Add all ingredients into a shaker with ice and shake until well-chilled.
# Strain into a chilled Nick & Nora glass.
# Express the oil of a coconut-mousse liqueur over the surface of the glass, then discard. (Alternatively, you can use pebble ice instead.)
# Garnish with freshly grated nutmeg.

# %%
print(get_recipe("bullet train", model, prefix="DRINK "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# DRINK RECIPE NAME
# bullet train
#
# DRINK RECIPE INGREDIENTS
# 1/2 ounce Jameson Irish whiskey
# 1/2 ounce Dolin Blanc Vermouth
# 1/2 ounce Cocchi Americano aperitif
# 1/4 ounce Kubler absinthe
# 1 dash The Bitter Truth Old Fashioned bitters
# Garnish: lemon twist
#
# DRINK RECIPE INSTRUCTIONS
# Add the whiskey, Dolin Blanc Vermouth, Cocchi Americano aperitif and bitters into a mixing glass with ice and stir until well-chilled.
# Strain into a coupe glass.
# Garnish with a lemon twist.

# %%
print(get_recipe("Berlin Night", model, prefix="DRINK "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# DRINK RECIPE NAME
# Berlin Night
#
# DRINK RECIPE INGREDIENTS
# 1 1/2 ounces Beefeater gin
# 1 1/2 ounces McClure’s pickling water
# 2 dashes Peychaud’s bitters
# Garnish: orange twist
#
# DRINK RECIPE INSTRUCTIONS
# Add all ingredients into a mixing glass with ice and stir until well-chilled.
# Strain into a chilled coupe glass.
# Garnish with an orange twist.

# %%
print(get_recipe("Tooth Fairy", model, prefix="DRINK "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# DRINK RECIPE NAME
# Tooth Fairy
#
# DRINK RECIPE INGREDIENTS
# 1 1/2 ounces London dry gin
# 1/2 ounce lemon juice, freshly squeezed
# 1/2 ounce simple syrup
# 1 dash Angostura bitters
# Garnish: lemon twist
#
# DRINK RECIPE INSTRUCTIONS
# Add the gin, lemon juice and simple syrup to a shaker with ice and shake until well-chilled.
# Strain into a chilled cocktail glass.
# Garnish with a lemon twist.

# %%
print(get_recipe("Butter Beer", model, prefix="DRINK "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# DRINK RECIPE NAME
# Butter Beer
#
# DRINK RECIPE INGREDIENTS
# 2 ounces bourbon
# 1/2 ounce Galliano L’Autentico liqueur
# 1/2 ounce honey syrup
# Garnish: brandied cherry
#
# DRINK RECIPE INSTRUCTIONS
# Add bourbon, Galliano L’Autentico liqueur, honey syrup and ice into a rocks glass over ice and stir.
# Garnish with a brandied cherry.

# %% [markdown]
# # Cake

# %%
prompts = "CAKE " + "RECIPE NAME\n"
encoded_prompt = tokenizer(prompts, return_tensors="pt").input_ids.to(device)
generated_sequence = model.generate(encoded_prompt, do_sample=True, max_length=600, temperature = 0.5, return_dict_in_generate=True, output_scores=True)
decoded_sequence = tokenizer.batch_decode(generated_sequence.sequences, skip_special_tokens=True)[0]
print(decoded_sequence)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# CAKE RECIPE NAME
# Pumpkin Crunch Cake with Cream Cheese Frosting
#
# CAKE RECIPE INGREDIENTS
# 1 teaspoon baking powder
# 1 teaspoon baking soda
# ¾ cup butter, softened
# 1 cup chopped pecans
# 2  eggs
# 1 cup evaporated milk
# 1 tablespoon ground cinnamon
# 1 teaspoon ground ginger
# 1 cup packed brown sugar
# 1 teaspoon pumpkin pie spice
# 1 teaspoon salt
# 1 cup white sugar
#
# CAKE RECIPE INSTRUCTIONS
# Preheat oven to 350 degrees F. Grease and flour a 9x13-inch pan.
# ...

# %%
print(get_recipe("Tooth Fairy", model, prefix="CAKE "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# CAKE RECIPE NAME
# Tooth Fairy
#
# CAKE RECIPE INGREDIENTS
# 2 cups all-purpose flour
# 1 teaspoon baking powder
# ½ teaspoon baking soda
# 1 cup butter, softened
# 3  eggs
# 1 cup milk
# 1 teaspoon salt
# 1 teaspoon vanilla extract
# 1 ½ cups white sugar
#
# CAKE RECIPE INSTRUCTIONS
# Preheat oven to 325 degrees F. Grease and flour a 9x13 inch pan.
# In a large bowl, cream together the butter and sugar until light and fluffy. Beat in the eggs one at a time, then stir in the vanilla. Beat in the flour mixture alternately with the milk. Pour batter into prepared pan.
# ...

# %%
print(get_recipe("beyond meat", model, prefix="CAKE "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# CAKE RECIPE NAME
# beyond meat
#
# CAKE RECIPE INGREDIENTS
# 3 cups all-purpose flour
# 1 teaspoon baking soda
# ½ cup butter
# ½ cup butter, softened
# 1 cup buttermilk
# 1 cup chopped pecans
# 2 cups confectioners' sugar
# 2  eggs
# 1 teaspoon ground cinnamon
# ½ teaspoon salt
# 1 teaspoon vanilla extract
# 1 ¼ cups white sugar
#
# CAKE RECIPE INSTRUCTIONS
# Preheat oven to 350 degrees F. Grease and flour two 9x13 inch pans.
# In medium bowl combine flour, white sugar, baking soda, cinnamon and salt. Set aside.
# In large mixer bowl combine eggs, buttermilk, vanilla and flour. Beat at low speed for 2 minutes. Add dry ingredients to the wet ingredients and mix until just combined. Don't beat well. Pour batter into prepared pans.
# ...

# %%
print(get_recipe("Hogwarts", model, prefix="CAKE "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# CAKE RECIPE NAME
# Hogwarts
#
# CAKE RECIPE INGREDIENTS
# 1 cup all-purpose flour
# 1 teaspoon baking soda
# 1 cup butter
# ½ cup butter
# ½ cup chopped pecans
# 1 cup confectioners' sugar
# 2  eggs
# ½ cup milk
# 1 cup packed brown sugar
# ½ teaspoon salt
# 1 teaspoon vanilla extract
# 1 cup white sugar
#
# CAKE RECIPE INSTRUCTIONS
# Preheat oven to 350 degrees F. Grease and flour a 9x13-inch loaf pan.
# Beat brown sugar, flour, and salt together in a bowl. Beat eggs, 1 at a time, into sugar mixture until fully incorporated; stir in flour mixture alternately with milk, beginning and ending with flour mixture. Pour batter into prepared loaf pan.
# ...

# %%
print(get_recipe("the Red Wedding", model, prefix="CAKE "))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# CAKE RECIPE NAME
# the Red Wedding
#
# CAKE RECIPE INGREDIENTS
# 1 ½ cups all-purpose flour
# 1 teaspoon baking powder
# 1 teaspoon baking soda
# ¼ cup butter, softened
# 1 cup buttermilk
# 1  egg
# 1 cup milk
# ½ teaspoon salt
# 1 teaspoon vanilla extract
# 1 ½ cups white sugar
#
# CAKE RECIPE INSTRUCTIONS
# Preheat oven to 350 degrees F. Grease and flour a 9x13-inch baking dish.
# Beat sugar and butter together in a large bowl with an electric mixer until light and fluffy. Add egg and mix until combined. Add flour, baking soda, baking powder, and salt; mix until just combined. Fold in buttermilk until just combined. Pour batter into the prepared pan.
# ...
